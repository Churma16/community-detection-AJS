# %%
import pandas as pd
import networkx as nx
import community.community_louvain as community
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# Membaca data dari file CSV
# data = pd.read_csv('net_IKN_Nusantara.csv')
data = pd.read_csv('net_IKN_Nusantara_New.csv')

# Mengambil kolom kedua dan ketiga
subset_data = data.iloc[:, [1, 2]]

# Membuat graf dari subset data
G = nx.from_pandas_edgelist(subset_data, source='from', target='to')

# Menjalankan algoritma Louvain
partition = community.best_partition(G)

# Menghitung nilai modularity
modularity = community.modularity(partition, G)

# Menampilkan nilai modularity
print("Nilai Modularity:", modularity)

# Mengatur posisi node pada graf
pos = nx.spring_layout(G)

# Mengambil jumlah komunitas
num_communities = max(partition.values()) + 1

# Membuat colormap dengan jumlah warna sesuai jumlah komunitas
cmap = cm.get_cmap('tab20', num_communities)

# Menentukan ukuran canvas
fig, ax = plt.subplots(figsize=(75, 75))

# Menggambar node pada graf dengan warna sesuai komunitas
node_colors = [cmap(partition[node]) for node in G.nodes]
nx.draw_networkx_nodes(G, pos, node_color=node_colors, cmap=cmap, ax=ax)

# Menggambar edge pada graf
nx.draw_networkx_edges(G, pos, ax=ax)

# Menampilkan label node dengan font size berdasarkan jumlah degree tertinggi di setiap komunitas
count = 0
max_com = []
arr_com = []
node_degrees_arr = []
max_degree_community = None

font_size=25
for community_id in set(partition.values()):
    community_nodes = [node for node, c_id in partition.items() if c_id == community_id]
    if len(community_nodes) > 2:
        count += 1
        subgraph = G.subgraph(community_nodes)
        node_degrees = dict(subgraph.degree())
        max_degree = max(node_degrees.values())
        labels = {node: node if degree == max_degree else '' for node, degree in node_degrees.items()}
        nx.draw_networkx_labels(subgraph, pos, labels=labels, font_size=font_size, ax=ax)
        print("\n")
        print("No", count, "Komunitas", community_id, ":", community_nodes)
        max_com.append(max_degree)
        arr_com.append(community_nodes)
        node_degrees_arr.append(node_degrees)
        
        print("Banyak Node:", max_degree + 1)


#take top 5 degree
max_com.sort(reverse=True)
top5 = max_com[:5]

# Sort the nested lists based on their length in descending order
arr_com.sort(key=len, reverse=True)

# Select the top 2 nested lists
top5node = arr_com[:5]

# Menampilkan jumlah komunitas
max_length_array = max(arr_com, key=len)
max_com_max = max(max_com)+1  # Get the maximum value from max_com list

print("===========================================")
print("Komunitas terbanyak memiliki: ", max_com_max,"Node")
print("Dengan Isi komunitas:", max_length_array)



# Menampilkan hasil visualisasi
plt.axis('off')
plt.show()
# Out:
# Nilai Modularity: 0.8793766901027569
# c:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\networkx\drawing\nx_pylab.py:433: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   node_collection = ax.scatter(
# No 1 Komunitas 0 : ['kantahkaboki', 'ditjentataruang', 'kantahkabmubar']
# Banyak Node: 3
#
#
# No 2 Komunitas 2 : ['kumparan', 'nntweetnn', 'antipki19', 'tempodotco', 'qoirudineki', 'afrchamp', 'sangiranflying', 'berlandgroup', 'tvrinewscom', 'amirelbahriy', 'politik___', 'jamalhabsy']
# Banyak Node: 10
#
#
# No 3 Komunitas 3 : ['jokowi', 'syarifiirvan', 'katadatacoid', 'avibkah', 'tmahartomo071', 'didikekky', 'tanlychat', 'cak_x01', 'bentangimaji', '_indonesiamaju_', 'mimi_chimmy', 'retnosetyow4t', 'laingenlisa', 'rahwan_asep', 'penjagajokowi1', 'sudar586028012', 'tolakbigotnkri', 'kelianbanjar_gk', '4y4nkz', 'elpanjullo', 'david_wijaya03', 'richardodhstio', 'richardo_tio', 'tio_richardo', 'dianaaurora96', 'arrayah43832329', 'aswadbaihaqi', 'maliqridwane', 'idey69881575', 'jisatu01', 'gem_1000x', 'dpdgppsultra', 'viksory', 'sejarahlokal', 'blasteerst', 'husainzain25652', 'kiyai_marufamin', 'prabowo', 'arsikamadja', 'gerbangnkri', 'jinjit_jinjit']
# Banyak Node: 15
#
#
# No 4 Komunitas 4 : ['waduhaku', 'asumsico', 'bolamatajkt', 'dani91setiawan', 'bakwanteles', 'botakcastello2', '___manofculture', 'danandaaanda', 'hopesxx_', 'syihabfarhani', 'mesincuciuang', 'altabaraspati', 'kakgupron', 'bearsarung', 'suarlanman', 'svytd', 'toolzark', 'ameshicaro', 'sipalingyadhi', 'riopribadie', 'rahel_setiawan', 'heizellee', 'catasthrovia', 'racilaziz', 'keepiin', 'omzyus', 'bayu_maz', 'monkey___mind', 'fskprly', 'youngest_knight', 'mpok_hanum', 'buukmarks', 'bluelinedot', 'rfanuzi', 'pctongkosong', 'buzz_ij', 'hylzira', 'silvi_indriyani', 'elzabarra21', 'eggyama', 'alyaratnadewi', 'santisartikaa', 'mmasukin', 'tamimfauzi', 'noahtarwin', 'dedynad_id', 'longjourney33', 'neologi62', 'yuzzah', 'diarta73', 'muhammadrafi_48', 'colpico', 'rf_48', 'kawulamu', 'bedigasans', 'hutriady', 'dfbrynd', 'puspitakartikaa', 'siperihitam', 'fish_goat6', '4rdn4n', 'dapp_adjie', 'randygoh', 'masgalsakti', 'dararinoona', 'erithsjohanh', 'wesomeaim', 'rinandarintha', 'aahmaadi_', 'jarrrrrrrrll', 'ezhafahrizal', 'rahmad__m', 'pep____', 'yelinpiranti', 'jungmoonjang123', 'idntimes']
# Banyak Node: 75
#
#
# No 5 Komunitas 6 : ['ngadi_min', 'poljokesid', 'atraa24', 'meigivalentina']
# Banyak Node: 4
#
#
# No 6 Komunitas 7 : ['oldfashionedly', 'blackcotanya', 'gawink159160', 'negeriku_ina', 'murphieku']
# Banyak Node: 5
#
#
# No 7 Komunitas 8 : ['covidberlalu', 'ikn_id', 'erzavindaf', 'igomagaz', 'kelestarianalam', 'kemenparekraf', 'sdnsedayu', 'dpopsamarinda', 'pppbajomulyo', 'houdianna', 'kotanusantara', 'ekrafkbb', 'kanioktaviani', 'joyogozali', 'axelrose234', 'gegewepe00', 'melabudiman', 'asokadea', 'malikmeong', 'tishashifa', 'sakuinformasi', 'brendyv']
# Banyak Node: 14
#
#
# No 8 Komunitas 9 : ['hansunriko', 'rii1naa', 'forjakeu', 'alshaibashihab', 'akomeng6', 'bank_aconk', 'yohanes_arb', 'rasyamahardika7', 'celebes07', 'anggita_lung', 'indones1akeren_', 'ranisor', 'aryprasetyo85', 'kalla_jengking', 'rasa2086', 'torrez_20_06', 'yulia_ns79', 'irakoestomo', 'komatkamiit', 'otak_sesendok', '_garu_da', 'id_emas2045', 'thoyiblupaplng', 'angelamaziiing', 'iqbalink13', 'apolloresor', 'magarapoo', 'putri_chiki', 'kkajikkaji', 'farahnathan24', 'ayahfarrel02', 'alves_ag88', 'aileenanjani', 'indones1aku', 'catatankaqihati', 'mosesrosi', 'musarudy_stpl', 'zheyenk26', 'nsjayaid', 'minietweets_', 'm1iikii', 'brudak_ultramen', 'inibarudak_well', 'laraswa2529']
# Banyak Node: 27
#
#
# No 9 Komunitas 10 : ['frprayogo', 'budipra87870630', 'kompascom', 'suryaborneo', 'suratmansoer', 'akunsudi', 'borneonkri', 'syamsud76579252', 'masterando', 'kompasdata', 'radiosmartfm', 'cnnindonesia', 'taswin50399860', 'metro_tv', 'tafdillah', 'franxvvv', 'ykomedian', 'tygrysku_', 'mhaikalfadhil', 'jemmyh8', 'rolaskendor', 'rommy_ardi', 'rizkiadinp_', 'lydiarumengan', 'andiyulman', 'piyuanker12', '_shab_7', 'uusbustami', 'rahma59429213', 'rayhan_yuda_pra']
# Banyak Node: 14
#
#
# No 10 Komunitas 11 : ['triwahyuutama15', 'aristrisno2', 'kemenpu', 'budisiswa01', 'titikterangnews', 'bobbypoerwana', 'igo_winata', 'dp6052', 'atdjasthias', 'datuksati', 'hasanahmutiara1', 'nyimaslomb4150', 't_araalla', 'radioelshinta', '_ardianata', 'fajarpuger', 'bingbinggrae', 'elshinta_tegal']
# Banyak Node: 16
#
#
# No 11 Komunitas 12 : ['dinarkemala', 'witelmedan', 'roniiesanjaya', 'nuansalika', 'djuru_achmad', 'raniyuningsih13', 'anisa__nisha___', 'nuraishwa2022', 'moranggg_mm', 'tialerita', 'chacaday', 'lisniamustika', 'farrdels', 'shalsazn', 'ayuwu1an', 'mayasilmili', 'shayllamutiara', 'noorannisarahma', 'asyifaning', 'rachmadinasheza', 'devipranayanti', 'virarahmadina', 'siskaharliyanti']
# Banyak Node: 23
#
#
# No 12 Komunitas 13 : ['rismayatimaya', 'projectm_org', 'cukupsatukata_']
# Banyak Node: 3
#
#
# No 13 Komunitas 14 : ['dcristnugroho', 'vaniaciprut', 'dr_moeldoko', 'akbar84_', 'softwarnews', 'adhitya_anand4', 'vini_vidi_veci', 'kitajokowi_xyz', 'abahjojo_', 'anibidadari', 'kakak_ica', 'reiawanmoeldoko', 'sahabat_hijroh', 'neng_di2', 'ta_k3n', 'nenk__d', 'pafarotte', 'plat___ag', 'bi3ir', 'dew0w1snu', 'pedjoeang_nkri', 'alya3231', 'mikadongaku22']
# Banyak Node: 16
#
#
# No 14 Komunitas 15 : ['pengenblueberry', 'narasitv', 'cho2mlhc']
# Banyak Node: 3
#
#
# No 15 Komunitas 16 : ['tehangatdingin', 'nothingmanytalk', 'tanyakanrl', 'jaecypeach', 'anggitpang']
# Banyak Node: 4
#
#
# No 16 Komunitas 18 : ['indahliliaz', 'meraaahputiiih', 'listiamanda', 'jimbe94127701']
# Banyak Node: 4
#
#
# No 17 Komunitas 22 : ['bs_vito', 'triwul82', 'gagaknewww', 'liaisti_1', 'lintang_ayoe', 'antoniuscdn', 'kepaargawinata2', 'budibongg', 'rifqiazizian', 'jilmannurhaman', 'wantahgdn__', 'ipoleksosbudmil', 'urrangawak', 'limbuibui4', 'xiaomei_99', 'r_min80', 'l0ve1ndonesia', 'bahamasjefry', '__rismawidiono_', 'ex_anaklolina', 'jauryjss', 'kotjo3', 'seruanhl', '_tenggangrasa', 'gi_n0ng', 'iromismet', '_25selawe', 'woda_johan', 'nkri_jokowisyoo', 'reymondabraham', 'kadekchandra', 'karyopahing', 'inilahdotcom', 'abdoeljegger202', 'bagiwang', 'bintangkec1l', 'wwleebest', 'rriskand', 'rian__az', 'xc1r3ng', 'itsmmm_13', 'wongkalibanteng', 'denmaspudji', 'hi_wonderwomen', 'naydonuts', 'abidinznl', 'nala_amirah', 'wo2_anis_orba_', 'rmlpas', 'dir1ku', 'p3weeice', 'jumianto_rk', 'prsdenri', 'chairilamri12', 'rahmans22161246', 'ngilmukantilaku', 'cahango45022699', 'abingsanca', 'ojayo_halim']
# Banyak Node: 44
#
#
# No 18 Komunitas 25 : ['ekoadji', 'hendrarprihadi', 'no2_thambenk', 'tegar19784522', 'roosfeary', 'momon_garuk44', 'asmarie_', 'doetaalam', 'julimakmur', 'daniel_supit', 'alzhaqyherry', 'setkabgoid', 'pramonoanung', 'menulrisa', 'reagansahudin', 'eveertth', 'ramafdy', 'prajnamu', 'wineva202', 'si_wisnu', 'deddyhariadi']
# Banyak Node: 13
#
#
# No 19 Komunitas 30 : ['ham1875240103', 'poldakaltim', 'polresbontang', 'farelyoel', 'sukoco_prabowo']
# Banyak Node: 5
#
#
# No 20 Komunitas 43 : ['aepishere', 'mediaindonesia', 'bisniscom']
# Banyak Node: 3
#
#
# No 21 Komunitas 49 : ['murahs3nyum', 'kemlu_ri', 'menlu_ri', 'mike_0402', 'yusiwansi']
# Banyak Node: 5
#
#
# No 22 Komunitas 53 : ['disewoti', 'opiik_piss', 'twitnurii', 'hatabomba_', 'a_latieff', 'sanusidotcom']
# Banyak Node: 6
#
#
# No 23 Komunitas 62 : ['detikcom', 'detik_sulsel', 'prasetiyoep', 'abehanief', 'ockysaputraa', 'ryanbakkaru', 'paidweb3', 'shandyjepret', 'babyjoenadira', 'yuskareem63', 'alimudi84052003', 'sandhey6', 'eknug', 'msmyoibae', 'punyadims', 'rananusantari', 'peterloveyou', 'adc14089', 'chris_azura', 'yanhendrik', 'oktayudhi', 'selasa98', 'fthrtwentyone', 'wztya9', 'damarholic', 'salwafhr30', 'vivacoid', 'ygndini_feb', 'azky_rk', 'imamwahidd', 'koeglodag', 'kurniawanricho', 'skcngwur', 'greenoto', 'zaeni_aditya', 'ifanmayo_', 'mesofullove_', 'yamjonkur', 'langx_wiratama', 'girolyar', 'dimasoemardjono', 'airazal', 'petroeq', 'agnan1923', 'idoymaridoy', 'mxrozaq', 'anang_ssanto', 'sammyfish13', 'vvchrstn', 'gebmoon', 'newsuriteladan', 'streamingdino', 'riofebrian02', 'dadangadi8', 'weiinnn', 'putirwn', 'raaraapo_', 'soobinjateng', 'dvntnggrn', 'juvejack', 'pokemon_udara', 'snowdropbae', 'agusssshhhhh', '1rf
# No 28 Komunitas 88 : ['sarmila20724164', 'pdi_perjuangan', 'mudha_satriya', 'khosammy', 'gigihpurno57425', 'riodamardjati', 'kacaspion__']
# Banyak Node: 7
#
#
# No 29 Komunitas 92 : ['bakorwil3malang', 'jatimpemprov', 'kominfojatim']
# Banyak Node: 3
#
#
# No 30 Komunitas 96 : ['marhaen777', 'tvonenews', 'yayanhariyant15', 'yodmaryodi', 'areeff', 'jbandara23']
# Banyak Node: 6
# ===========================================
# Komunitas terbanyak memiliki:  133 Node
# Dengan Isi komunitas: ['detikcom', 'detik_sulsel', 'prasetiyoep', 'abehanief', 'ockysaputraa', 'ryanbakkaru', 'paidweb3', 'shandyjepret', 'babyjoenadira', 'yuskareem63', 'alimudi84052003', 'sandhey6', 'eknug', 'msmyoibae', 'punyadims', 'rananusantari', 'peterloveyou', 'adc14089', 'chris_azura', 'yanhendrik', 'oktayudhi', 'selasa98', 'fthrtwentyone', 'wztya9', 'damarholic', 'salwafhr30', 'vivacoid', 'ygndini_feb', 'azky_rk', 'imamwahidd', 'koeglodag', 'kurniawanricho', 'skcngwur', 'greenoto', 'zaeni_aditya', 'ifanmayo_', 'mesofullove_', 'yamjonkur', 'langx_wiratama', 'girolyar', 'dimasoemardjono', 'airazal', 'petroeq', 'agnan1923', 'idoymaridoy', 'mxrozaq', 'anang_ssanto', 'sammyfish13', 'vvchrstn', 'gebmoon', 'newsuriteladan', 'streamingdino', 'riofebrian02', 'dadangadi8', 'weiinnn', 'putirwn', 'raaraapo_', 'soobinjateng', 'dvntnggrn', 'juvejack', 'pokemon_udara', 'snowdropbae', 'agusssshhhhh', '1rfantastic', 'iantrucker', 'awindul', 'officialwawan', 'putrosukarno', 'talakuaelwen95', 'tulip84882930', 'mugiahdht', 'milanista2103', 'lilikshandhie14', 'kutang_hitam', 'dhu_dhuan', 'yotifolk', 'barca_joss', 'kopimovie', 'jeongshafa', 'itsaufarfajar', 'danielandrians', 'baru354', 'ziyadu_r', 'itabmth', 'elichika2525', 'ydknrf', 'adoorabie', 'panggilsajapida', 'achmadbandi', 'asmaraidaleni', 'clynophilert', 'm_kael', 'msnrng', 'rizwandhaimawa1', 'erisadgita', 'itswildanwill', 'flourentt_cris', 'entah3383', 'nell20000', 'witaresw', 'susaaahtidur', 'novita_kaunang', 'reskisural', 'vitabangun', 'marcellrudee', 'tsupersubs', 'novanpramadi12', 'limlim672', 'artregular', 'akbar_gremory', 'officialkjti', 'imanurak_269', 'kancilcungkring', 'msalmanhdr', 'anorexicats', 'himechwaan', 'kak_veronika', 'rose_ifntday6', 'naeni_romayati', 'zerahyaa', 'daffastyaa', 'kokoaja4', 'retywie', 'astagakenapalu', 'kristybambooart', 'andreallian', 'pemudaharapannn', 'ysbcht_', 'ichigo97538820', 'xoneebenaja', 'ndrys_', 'riandi_12', 'estersagala4', 'infoindonesiaaa']

# %%
print("5 Komunitas dengan node terbanyak:")
for items in top5node:
    print(items)
    print("Banyak Node:", len(items))
    print("===========================================")
# Out:
# 5 Komunitas dengan node terbanyak:
# ['hansunriko', 'rii1naa', 'forjakeu', 'alshaibashihab', 'akomeng6', 'bank_aconk', 'yohanes_arb', 'rasyamahardika7', 'celebes07', 'anggita_lung', 'indones1akeren_', 'ranisor', 'aryprasetyo85', 'kalla_jengking', 'rasa2086', 'torrez_20_06', 'yulia_ns79', 'irakoestomo', 'komatkamiit', 'otak_sesendok', '_garu_da', 'id_emas2045', 'thoyiblupaplng', 'angelamaziiing', 'iqbalink13', 'apolloresor', 'magarapoo', 'putri_chiki', 'kkajikkaji', 'farahnathan24', 'ayahfarrel02', 'alves_ag88', 'aileenanjani', 'indones1aku', 'catatankaqihati', 'mosesrosi', 'musarudy_stpl', 'zheyenk26', 'nsjayaid', 'minietweets_', 'm1iikii', 'brudak_ultramen', 'inibarudak_well', 'laraswa2529']
# Banyak Node: 44
# ===========================================

# %%
print("Node dengan degree terbanyak:")
# Sort the dictionaries based on their values in descending order
sorted_dicts = sorted(node_degrees_arr, key=lambda x: max(x.values()), reverse=True)
sorted_dicts_highestvalue = [{k: v for k, v in sorted(d.items(), key=lambda x: x[1], reverse=True)} for d in sorted_dicts]
# Print the top two dictionaries
top5nodecommunities = []
for i in sorted_dicts_highestvalue[:5]:
    mostNode=list(i.keys())
    firstMostNode=mostNode[0]
    top5nodecommunities.append(firstMostNode)
    # print(top5nodecommunities)
    print(len(i))
    print(i)
    
print('=====================================')
print(top5nodecommunities)
# Out:
# Node dengan degree terbanyak:
# 134
# {'detikcom': 132, 'ockysaputraa': 2, 'newsuriteladan': 1, 'punyadims': 1, 'xoneebenaja': 1, 'nell20000': 1, 'kutang_hitam': 1, 'elichika2525': 1, 'limlim672': 1, 'anorexicats': 1, 'girolyar': 1, 'juvejack': 1, 'marcellrudee': 1, 'tsupersubs': 1, '1rfantastic': 1, 'tulip84882930': 1, 'kopimovie': 1, 'soobinjateng': 1, 'andreallian': 1, 'weiinnn': 1, 'vvchrstn': 1, 'raaraapo_': 1, 'idoymaridoy': 1, 'itsaufarfajar': 1, 'agusssshhhhh': 1, 'azky_rk': 1, 'kurniawanricho': 1, 'officialkjti': 1, 'novanpramadi12': 1, 'selasa98': 1, 'riofebrian02': 1, 'retywie': 1, 'kancilcungkring': 1, 'himechwaan': 1, 'rananusantari': 1, 'adoorabie': 1, 'susaaahtidur': 1, 'snowdropbae': 1, 'sammyfish13': 1, 'ziyadu_r': 1, 'msnrng': 1, 'oktayudhi': 1, 'flourentt_cris': 1, 'anang_ssanto': 1, 'streamingdino': 1, 'officialwawan': 1, 'langx_wiratama': 1, 'peterloveyou': 1, 'fthrtwentyone': 1, 'novita_kaunang': 1, 'vitabangun': 1, 'entah3383': 1, 'reskisural': 1, 'ifanmayo_': 1, 'airazal': 1, 'barca_joss': 1, 'agnan1923': 1, 'prasetiyoep': 1, 'dimasoemardjono': 1, 'danielandrians': 1, 'zaeni_aditya': 1, 'asmaraidaleni': 1, 'mesofullove_': 1, 'achmadbandi': 1, 'greenoto': 1, 'babyjoenadira': 1, 'yotifolk': 1, 'itswildanwill': 1, 'naeni_romayati': 1, 'gebmoon': 1, 'rose_ifntday6': 1, 'vivacoid': 1, 'mxroz
# 44
# {'_garu_da': 26, 'torrez_20_06': 26, 'bank_aconk': 24, 'forjakeu': 23, 'komatkamiit': 22, 'hansunriko': 21, 'yulia_ns79': 16, 'thoyiblupaplng': 7, 'akomeng6': 7, 'indones1akeren_': 7, 'celebes07': 7, 'rasyamahardika7': 7, 'alshaibashihab': 7, 'iqbalink13': 6, 'yohanes_arb': 6, 'apolloresor': 6, 'anggita_lung': 6, 'ranisor': 6, 'otak_sesendok': 5, 'rii1naa': 5, 'putri_chiki': 4, 'catatankaqihati': 4, 'indones1aku': 3, 'ayahfarrel02': 3, 'kalla_jengking': 2, 'zheyenk26': 2, 'irakoestomo': 2, 'rasa2086': 2, 'laraswa2529': 1, 'minietweets_': 1, 'nsjayaid': 1, 'm1iikii': 1, 'farahnathan24': 1, 'brudak_ultramen': 1, 'angelamaziiing': 1, 'id_emas2045': 1, 'inibarudak_well': 1, 'aryprasetyo85': 1, 'mosesrosi': 1, 'aileenanjani': 1, 'magarapoo': 1, 'alves_ag88': 1, 'kkajikkaji': 1, 'musarudy_stpl': 1}
# =====================================
# ['detikcom', 'yradianto', 'asumsico', 'triwul82', '_garu_da']

# %%
class FindUser:
    def __init__(self, data, user):
        self.data = data
        self.user = user
        self.found = False
        self.reply = None
        self.rt = None
        for i in data.index:
            if(data['author'][i].lower() == self.user):
                self.author = data['author'][i]
                self.title = data['title'][i]
                self.label = data['sentiment_label'][i]
                self.followers = data['user_followers_count'][i]
                self.status_count = data['user_statuses_count'][i]
                self.found = True
                break
            self.author = None
            self.title = None
            self.label = None
            self.followers = None
            self.status_count = None

    def retweet(self):
        retweets = []
        for i in data.index:
            if(str(self.data['retweeted_screen_name'][i]).lower() == self.user):
                retweets.append(self.data['author'][i])
        # if retweets:
        #     return retweets
        return retweets
        # print(self.retweet)
    
    def reply(self):
        replys = []
        for i in data.index:
            user = data['in_reply_to_screen_name'][i]
            if(user == self.user):
                if(self.data['in_reply_to_screen_name'][i] != self.data['author'][i]):
                    replys.append([self.data['author'][i], self.data['description'][i]])
        if replys:
            return replys
        return None



count = 0
for items in top5nodecommunities:
    count= count+1
    data1 = pd.read_csv('IKN_Nusantara_new.csv')
    community = items
    firstuser = items
    user = FindUser(data1, firstuser)
    retweets = user.retweet()
    print(firstuser)
    print("Komunitas", count, ":", community)
    print("User: ", user.author, end="\n")
    print("Followers: ", f"{user.followers:,}", end="\n")
    print("Status Count: ", f"{user.status_count:,}", end="\n")
    print("Tweet: ", user.title, end="\n")
    print("Label: ", user.label, end="\n")
    print("Retweet: ", retweets, end="\n")
    print("Reply: ", user.reply, end="\n")
    print("===========================================")
# Out:
# detikcom
# Komunitas 1 : detikcom
# User:  detikcom
# Followers:  20,178,986
# Status Count:  2,206,369
# Tweet:  Sebanyak 2.500 Aparatur Sipil Negara (ASN) akan mulai dipindah secara bertahap ke Ibu Kota Negara (IKN) Nusantara, Kalimantan Timur (Kaltim) tahun 2024. #ASN #IKN  Via: @detik_sulsel  https://t.co/ckujwYoIRT
# Label:  Positive
# Retweet:  ['RyanBakkaru', 'Ockysaputraa', 'abehanief', 'PrasetiyoEp', 'InfoIndonesiaaa', 'EsterSagala4', 'Riandi_12', 'ndrys_', 'XOneeBenaJa', 'ichigo97538820', 'ysbcht_', 'pemudaharapannn', 'andreallian', 'KristyBambooArt', 'astagakenapalu', 'retywie', 'KokoAja4', 'Daffastyaa', 'zerahyaa', 'naeni_romayati', 'Rose_ifntday6', 'Kak_Veronika', 'himechwaan', 'anorexicats', 'msalmanhdr', 'KancilCungkring', 'imanurak_269', 'Officialkjti', 'Akbar_Gremory', 'ArtRegular', 'limlim672', 'novanpramadi12', 'tsupersubs', 'marcellrudee', 'vitabangun', 'ReskisuraL', 'Novita_Kaunang', 'susaaahtidur', 'witaresw', 'nell20000', 'entah3383', 'flourentt_cris', 'itswildanwill', 'ErisaDgita', 'RizwandhaImawa1', 'msnrng', 'M_KAEL', 'clynophilert', 'AsmaraidaLeni', 'AchmadBandi', 'panggilsajapida', 'adoorabIe', 'ydknrf', 'Elichika2525', 'itabmth', '4rdn4n', 'Ziyadu_R', 'baru354', 'danielandrians', 'itsaufarfajar', 'jeongshafa', 'kopimovie', 'barca_joss', 'yotifolk', 'dhu_dhuan', 'Kutang_Hitam', 'LiLikShandhie14', 'Milanista2103', 'mhaikalfadhil', 'mugiahdht', 'Tulip84882930', 'talakuaelwen95', 'PutroSukarno', 'officialwawan', 'Ockysaputraa', 'awindul', 'iantrucker', '1rfantastic', 'agusssshhhhh', 'snowdropbae', 'Pokemon_Udara', 'juvejack', 'dvntnggrn', 'soobinjateng', 'raaraapo_', 'putirwn', 'Weiinnn', 'dadangadi8', 'riofebrian02', 'streamingdino', 'NewsuriTeladan', 'gebmoon', 'vvchrstn', 'sammyfish13', 'Anang_ssanto', 'mxrozaq', 'idoymaridoy', 'agnan1923', 'petroeq', 'airazal', 'dimasoemardjono', 'aahmaadi_', 'GiroLyar', 'Langx_Wiratama', 'yamjonkur', 'mesofullove_', 'IfanMayo_', 'zaeni_aditya', 'GreenOTO', 'skcngwur', 'KurniawanRicho', 'koeglodag', 'imamwahidd', 'Azky_RK', 'ygndini_feb', 'salwafhr30', 'Damarholic', 'wztya9', 'Fthrtwentyone', 'Selasa98', 'oktayudhi', 'yanhendrik', 'chris_azura', 'adc14089', 'peterloveyou', 'rananusantari', 'punyadims', 'msmyoibae', 'eknug', 'sandhey6', 'Alimudi84052003', 'yuskareem63', 'piyuanker12', 'BabyJoenadira']
# Reply:  None
# ===========================================
# yradianto
# Komunitas 2 : yradianto
# User:  YRadianto
# Followers:  87,472
# Status Count:  376,727
# Tweet:  Pohon Hayat  Inilah Pohon Hayat yang diresmikan Presiden Joko Widodo sebagai logo Ibu Kota Nusantara di Istana Negara Jakarta kemarin (30 Mei 2023).  Selamat dan terima kasih buat Mas Aulia Akbar yang desainnya terpilih.  https://t.co/VzLNOxxUhj https://t.co/PfbmlJL4gv
# Label:  Positive
# Retweet:  ['retnoeddy', 'DoeztWae', 'Teguh19699297', 'luthfi78wahab', 'BuzzsBowie', 'suryaaa64', 'abah_saka', 'JarotIskariot', 'rafherren290188', 'Gunadi84380182', 'AgoraFX', 'to_jentak', 'urehheru', 'gamispendek', 'idjorojorojo', 'BuahsegarTandan', 'arjunakiriti', 'rania_rohani', 'rubiavianto', 'aunb132', 'JannesHutajulu', 'TuamaLeleko', 'Didiek09165668', 'fadjar2411', 'dade_fuad', 'EMuliantoro', 'HermanARohman4', 'HRMalik12', 'faridariadno', 'warenkbae', 'kusumovina', 'whitedodo', 'iyat_jabbari', 'Manse_Mangat', 'BolangRaddick', 'AzazelRich', 'gdwi164', 'lek_brewok', 'TreeKedua', 'roysahadoen', 'OnJustAnt', 'liestevan', 'bis0234', 'achzam_prabu', 'suradiparlan5', 'Widodo2017', 'levdammers', 'Frankie54832617', 'berbatu4', 'MulyadiSaediman', 'BungaNdaru', 'hatewe369', 'pierreicon', 'suroso_noto6', 'NKRIjayalah', 'Yonno06667468', 'liest07list', 'langlangbuana__', 'woda_johan', 'lanang_jadoel', 'PiusLeza5', 'jiwe3107', 'adrianteja', 'YuniYun94319256', 'afif_lmg', 'LaingenLisa', 'de_kvn2', 'HerryKeytimu', 'BiBoDah1', 'Widya99999']
# Reply:  None
# ===========================================
# asumsico
# Komunitas 3 : asumsico
# User:  asumsico
# Followers:  328,107
# Status Count:  29,554
# Tweet:  Pemerintah secara terbuka mengajak seluruh masyarakat Indonesia untuk berpartisipasi memilih logo kota Nusantara sebagai Ibu Kota Negara yang baru. https://t.co/SmMZFVFWtJ
# Label:  Positive
# Retweet:  ['jungmoonjang123', 'yelinpiranti', 'pep____', 'rahmad__m', 'ezhafahrizal', 'jarrrrrrrrll', 'aahmaadi_', 'rinandarintha', 'wesomeaim', 'erithsjohanh', 'dararinoona', 'masGalsakti', 'randygoh', 'dapp_adjie', '4rdn4n', 'Fish_Goat6', 'siperihitam', 'puspitakartikaa', 'dfbrynd', 'hutriady', 'bedigasans', 'kawulamu', 'RF_48', 'syarifiirvan', 'triwahyuutama15', 'FRPrayogo', 'colpico', 'MuhammadRafi_48', 'Diarta73', 'yuzzah', 'Neologi62', 'longjourney33', 'DedyNad_id', 'noahtarwin', 'tamimfauzi', 'MMasukin', 'santisartikaa', 'AlyaRatnadewi', 'eggyama', 'elzabarra21', 'silvi_indriyani', 'hylzira', 'buzz_IJ', 'pctongkosong', 'rfanuzi', 'Bluelinedot', 'buukmarks', 'Mpok_Hanum', 'youngest_knight', 'fskprly', 'monkey___mind', 'bayu_maz', 'Omzyus', 'keepiin', 'racilaziz', 'catasthrovia', 'Heizellee', 'Rahel_Setiawan', 'riopribadie', 'sipalingyadhi', 'ameshicaro', 'toolzark', 'svytd', 'suarlanman', 'bearsarung', 'KakGupron', 'altabaraspati', 'mesincuciuang', 'syihabfarhani', 'hopesxx_', 'danandaaanda', '___manofculture', 'BotakCastello2', 'bakwanteles', 'Dani91Setiawan', 'bolamatajkt', 'WaduhAku']
# Reply:  None
# ===========================================
# triwul82
# Komunitas 4 : triwul82
# User:  triwul82
# Followers:  39,589
# Status Count:  354,347
# Tweet:  Pemerintah menggelar pemilihan logo Ibu Kota Negara (IKN) Nusantara berhadiah sepeda motor listrik. Pemilihan logo ini bisa diikuti masyarakat umum. Logo dengan pemilih terbanyak nantinya akan digunakan sebagai logo resmi IKN. Proses pemilihan (voting) logo IKN Nusantara sudah… https://t.co/VUxp9Ui73j https://t.co/JC7T0QuDvj
# Label:  Positive
# Retweet:  ['seruanhl', 'Kotjo3', 'JauryJss', 'ex_AnakLolina', '__RismaWidiono_', 'BahamasJefry', 'L0ve1ndonesia', 'R_min80', 'XiaoMei_99', 'Yulia_NS79', 'LimBuiBui4', 'Urrangawak', 'IPOLEKSOSBUDMIL', 'wantahgdn__', 'JilmanNurhaman', 'rifqiazizian', 'budibongg', 'KepaArgawinata2', 'AntoniusCDN', 'lintang_ayoe', 'Liaisti_1', 'dcristnugroho', 'GagakNewww', 'bs_vito', 'BahamasJefry', '__RismaWidiono_']
# Reply:  None
# ===========================================
# _garu_da
# Komunitas 5 : _garu_da
# User:  _garu_da
# Followers:  3,579
# Status Count:  53,690
# Tweet:  RT @Komatkamiit: Alhamdulillah bisa bernafas lega.  Exco PSSI Arya Sinulingga ungkapkan sanksi FIFA tidak memengaruhi rencana membangun tra…
# Label:  Positive
# Retweet:  ['Otak_sesendok', 'Komatkamiit', 'Thoyiblupaplng', 'iqbalink13', 'forjakeu', 'apolloresor', 'Putri_Chiki', 'Bank_Aconk', 'Torrez_20_06', 'Rii1naa', 'Anggita_lung', 'Ranisor', 'Akomeng6', 'Yohanes_ARB', 'Indones1aKeren_', 'Celebes07', 'RasyaMahardika7', 'kadekchandra', 'AlshaibaShihab', 'Komatkamiit', 'catatankaqihati', 'Bank_Aconk', 'AlshaibaShihab', 'Anggita_lung', 'LarasWa2529', 'Thoyiblupaplng', 'Zheyenk26', 'inibarudak_well', 'brudak_ultramen', 'Indones1aKeren_', 'RasyaMahardika7', 'M1iikii', 'Akomeng6']
# Reply:  None
# ===========================================

# %%
#get the sentiment label
new_sub_array = []
test_sub_array = []
sentiment_label = []
for sub_list in top5node:
    for node in sub_list:
        data1 = pd.read_csv('IKN_Nusantara_new.csv')
        user = FindUser(data1, node)
        new_sub_array.append(user.label)
    sentiment_label.append(new_sub_array)
    new_sub_array = []

# Mengetahui tanggapan yang keluar pada tiap komunitas
count = 0

for sub_sentiment_label in sentiment_label:
    count += 1
    print("===========================================")
    print("Komunitas", count)
    print("Positif: ", sub_sentiment_label.count("Positive"))
    print("Negatif: ", sub_sentiment_label.count("Negative"))
    print("Netral: ", sub_sentiment_label.count("Neutral"))
# Out:
# ===========================================
# Komunitas 1
# Positif:  129
# Negatif:  5
# Netral:  0
# ===========================================
# Komunitas 2
# Positif:  76
# Negatif:  0
# Netral:  0
# ===========================================
# Komunitas 3
# Positif:  76
# Negatif:  0
# Netral:  0
# ===========================================
# Komunitas 4
# Positif:  55
# Negatif:  0
# Netral:  4
# ===========================================
# Komunitas 5
# Positif:  39
# Negatif:  5
# Netral:  0
