# %%
import pandas as pd
import networkx as nx
import community
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# Membaca data dari file CSV
# data = pd.read_csv('net_IKN_Nusantara.csv')
data = pd.read_csv('net_IKN_Nusantara_New.csv')

# Mengambil kolom kedua dan ketiga
subset_data = data.iloc[:, [1, 2]]

# Membuat graf dari subset data
G = nx.from_pandas_edgelist(subset_data, source='from', target='to')

# Menjalankan algoritma Louvain
partition = community.best_partition(G)

# Mengatur posisi node pada graf
pos = nx.spring_layout(G)

# Mengambil jumlah komunitas
num_communities = max(partition.values()) + 1

# Membuat colormap dengan jumlah warna sesuai jumlah komunitas
cmap = cm.get_cmap('tab20', num_communities)

# Menentukan ukuran canvas
fig, ax = plt.subplots(figsize=(75, 75))

# Menggambar node pada graf dengan warna sesuai komunitas
node_colors = [cmap(partition[node]) for node in G.nodes]
nx.draw_networkx_nodes(G, pos, node_color=node_colors, cmap=cmap, ax=ax)

# Menggambar edge pada graf
nx.draw_networkx_edges(G, pos, ax=ax)

# Menampilkan label node dengan font size berdasarkan jumlah degree tertinggi di setiap komunitas
count = 0
max_com = []
arr_com = []
node_degrees_arr = []
max_degree_community = None

font_size=25
for community_id in set(partition.values()):
    community_nodes = [node for node, c_id in partition.items() if c_id == community_id]
    if len(community_nodes) > 2:
        count += 1
        subgraph = G.subgraph(community_nodes)
        node_degrees = dict(subgraph.degree())
        max_degree = max(node_degrees.values())
        labels = {node: node if degree == max_degree else '' for node, degree in node_degrees.items()}
        nx.draw_networkx_labels(subgraph, pos, labels=labels, font_size=font_size, ax=ax)
        print("\n")
        print("No", count, "Komunitas", community_id, ":", community_nodes)
        max_com.append(max_degree)
        arr_com.append(community_nodes)
        node_degrees_arr.append(node_degrees)
        
        print("Banyak Node:", max_degree + 1)


#take top 5 degree
max_com.sort(reverse=True)
top5 = max_com[:5]

# Sort the nested lists based on their length in descending order
arr_com.sort(key=len, reverse=True)

# Select the top 2 nested lists
top5node = arr_com[:5]

# Menampilkan jumlah komunitas
max_length_array = max(arr_com, key=len)
max_com_max = max(max_com)+1  # Get the maximum value from max_com list

print("===========================================")
print("Komunitas terbanyak memiliki: ", max_com_max,"Node")
print("Dengan Isi komunitas:", max_length_array)



# Menampilkan hasil visualisasi
plt.axis('off')
plt.show()
# Out:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\networkx\drawing\nx_pylab.py:433: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   node_collection = ax.scatter(
# No 1 Komunitas 0 : ['kantahkaboki', 'ditjentataruang', 'kantahkabmubar']
# Banyak Node: 3
#
#
# No 2 Komunitas 2 : ['kumparan', 'nntweetnn', 'antipki19', 'tempodotco', 'qoirudineki', 'afrchamp', 'sangiranflying', 'berlandgroup', 'tvrinewscom', 'amirelbahriy', 'politik___', 'jamalhabsy']
# Banyak Node: 10
#
#
# Banyak Node: 27
#
#
# No 8 Komunitas 12 : ['covidberlalu', 'ikn_id', 'erzavindaf', 'igomagaz', 'kelestarianalam', 'kemenparekraf', 'sdnsedayu', 'dpopsamarinda', 'pppbajomulyo', 'houdianna', 'kotanusantara', 'ekrafkbb', 'kanioktaviani', 'joyogozali', 'axelrose234', 'gegewepe00', 'melabudiman', 'asokadea', 'malikmeong', 'tishashifa', 'sakuinformasi', 'brendyv']
# Banyak Node: 14
#
#
# No 9 Komunitas 14 : ['triwahyuutama15', 'aristrisno2', 'kemenpu', 'budisiswa01', 'titikterangnews', 'bobbypoerwana', 'igo_winata', 'dp6052', 'atdjasthias', 'datuksati', 'hasanahmutiara1', 'nyimaslomb4150', 't_araalla', 'radioelshinta', '_ardianata', 'fajarpuger', 'bingbinggrae', 'elshinta_tegal']
# Banyak Node: 16
#
#
# No 10 Komunitas 15 : ['maximilan_wolf', 'nogososroasli', '_mbaksri_', 'cinggaro']
# Banyak Node: 6
#
#
# No 11 Komunitas 16 : ['dinarkemala', 'witelmedan', 'roniiesanjaya', 'nuansalika', 'djuru_achmad', 'raniyuningsih13', 'anisa__nisha___', 'nuraishwa2022', 'moranggg_mm', 'tialerita', 'chacaday', 'lisniamustika', 'farrdels', 'shalsazn', 'ayuwu1an', 'mayasilmili', 'shayllamutiara', 'noorannisarahma', 'asyifaning', 'rachmadinasheza', 'devipranayanti', 'virarahmadina', 'siskaharliyanti']
# Banyak Node: 23
#
#
# No 12 Komunitas 18 : ['dcristnugroho', 'vaniaciprut', 'dr_moeldoko', 'akbar84_', 'softwarnews', 'adhitya_anand4', 'vini_vidi_veci', 'kitajokowi_xyz', 'abahjojo_', 'anibidadari', 'kakak_ica', 'reiawanmoeldoko', 'sahabat_hijroh', 'neng_di2', 'ta_k3n', 'nenk__d', 'pafarotte', 'plat___ag', 'bi3ir', 'dew0w1snu', 'pedjoeang_nkri', 'alya3231', 'mikadongaku22']
# Banyak Node: 16
#
#
# No 13 Komunitas 19 : ['frprayogo', 'budipra87870630', 'kompascom', 'suryaborneo', 'suratmansoer', 'akunsudi', 'borneonkri', 'syamsud76579252', 'masterando', 'kompasdata', 'radiosmartfm', 'cnnindonesia', 'taswin50399860', 'metro_tv', 'tafdillah', 'franxvvv', 'ykomedian', 'tygrysku_', 'mhaikalfadhil', 'jemmyh8', 'rolaskendor', 'rommy_ardi', 'rizkiadinp_', 'lydiarumengan', 'andiyulman', 'piyuanker12', '_shab_7', 'uusbustami', 'rahma59429213', 'rayhan_yuda_pra']
# Banyak Node: 14
#
#
# No 14 Komunitas 21 : ['pengenblueberry', 'narasitv', 'cho2mlhc']
# Banyak Node: 3
#
#
# No 15 Komunitas 23 : ['tehangatdingin', 'nothingmanytalk', 'tanyakanrl', 'jaecypeach', 'anggitpang']
# Banyak Node: 4
#
#
# No 16 Komunitas 25 : ['indahliliaz', 'meraaahputiiih', 'listiamanda', 'jimbe94127701']
# Banyak Node: 4
#
#
# No 17 Komunitas 29 : ['bs_vito', 'triwul82', 'gagaknewww', 'liaisti_1', 'lintang_ayoe', 'antoniuscdn', 'kepaargawinata2', 'budibongg', 'rifqiazizian', 'jilmannurhaman', 'wantahgdn__', 'ipoleksosbudmil', 'urrangawak', 'limbuibui4', 'xiaomei_99', 'r_min80', 'l0ve1ndonesia', 'bahamasjefry', '__rismawidiono_', 'ex_anaklolina', 'jauryjss', 'kotjo3', 'seruanhl', '_tenggangrasa', 'gi_n0ng', 'iromismet', '_25selawe', 'woda_johan', 'nkri_jokowisyoo', 'reymondabraham', 'kadekchandra', 'karyopahing', 'inilahdotcom', 'abdoeljegger202', 'bagiwang', 'bintangkec1l', 'wwleebest', 'rriskand', 'rian__az', 'xc1r3ng', 'itsmmm_13', 'wongkalibanteng', 'denmaspudji', 'hi_wonderwomen', 'naydonuts', 'abidinznl', 'nala_amirah', 'wo2_anis_orba_', 'rmlpas', 'dir1ku', 'p3weeice', 'jumianto_rk', 'prsdenri', 'chairilamri12', 'rahmans22161246', 'ngilmukantilaku', 'cahango45022699', 'abingsanca', 'ojayo_halim']
# Banyak Node: 44
#
#
# No 18 Komunitas 33 : ['sheilla_ang', 'abang_atus', 'aulingkel48096', 'virgol2049', 'mgayatri306', 'ghizch4', 'faried58022486']
# Banyak Node: 9
#
#
# No 19 Komunitas 34 : ['sarmila20724164', 'pdi_perjuangan', 'mudha_satriya', 'khosammy', 'gigihpurno57425', 'riodamardjati', 'kacaspion__']
# Banyak Node: 7
#
#
# No 20 Komunitas 36 : ['ekoadji', 'hendrarprihadi', 'no2_thambenk', 'tegar19784522', 'roosfeary', 'momon_garuk44', 'asmarie_', 'doetaalam', 'julimakmur', 'daniel_supit', 'alzhaqyherry', 'setkabgoid', 'pramonoanung', 'menulrisa', 'reagansahudin', 'eveertth', 'ramafdy', 'prajnamu', 'wineva202', 'si_wisnu', 'deddyhariadi']
# Banyak Node: 13
#
#
# No 21 Komunitas 43 : ['ham1875240103', 'poldakaltim', 'polresbontang', 'farelyoel', 'sukoco_prabowo']
# Banyak Node: 5
#
#
# No 22 Komunitas 57 : ['aepishere', 'mediaindonesia', 'bisniscom']
# Banyak Node: 3
#
#
# No 23 Komunitas 58 : ['bakorwil3malang', 'jatimpemprov', 'kominfojatim']
# Banyak Node: 3
#
#
# No 24 Komunitas 62 : ['oholdeuboi', 'yradianto', 'koffie_lover', 'wdtu', 'ctr_bowo', 'cahkuwut', 'effendiristriy1', 'andida_alamsyah', 'widya99999', 'bibodah1', 'herrykeytimu', 'de_kvn2', 'afif_lmg', 'yuniyun94319256', 'adrianteja', 'jiwe3107', 'piusleza5', 'lanang_jadoel', 'langlangbuana__', 'liest07list', 'yonno06667468', 'nkrijayalah', 'suroso_noto6', 'pierreicon', 'hatewe369', 'bungandaru', 'mulyadisaediman', 'berbatu4', 'frankie54832617', 'levdammers', 'wid
 'msalmanhdr', 'anorexicats', 'himechwaan', 'kak_veronika', 'rose_ifntday6', 'naeni_romayati', 'zerahyaa', 'daffastyaa', 'kokoaja4', 'retywie', 'astagakenapalu', 'kristybambooart', 'andreallian', 'pemudaharapannn', 'ysbcht_', 'ichigo97538820', 'xoneebenaja', 'ndrys_', 'riandi_12', 'estersagala4', 'infoindonesiaaa']

# %%
print("5 Komunitas dengan node terbanyak:")
for items in top5node:
    print(items)
    print("Banyak Node:", len(items))
    print("===========================================")
# Out:
# 5 Komunitas dengan node terbanyak:
# ['detikcom', 'detik_sulsel', 'prasetiyoep', 'abehanief', 'ockysaputraa', 'ryanbakkaru', 'paidweb3', 'shandyjepret', 'babyjoenadira', 'yuskareem63', 'alimudi84052003', 'sandhey6', 'eknug', 'msmyoibae', 'punyadims', 'rananusantari', 'peterloveyou', 'adc14089', 'chris_azura', 'yanhendrik', 'oktayudhi', 'selasa98', 'fthrtwentyone', 'wztya9', 'damarholic', 'salwafhr30', 'vivacoid', 'ygndini_feb', 'azky_rk', 'imamwahidd', 'koeglodag', 'kurniawanricho', 'skcngwur', 'greenoto', 'zaeni_aditya', 'ifanmayo_', 'mesofullove_', 'yamjonkur', 'langx_wiratama', 'girolyar', 'dimasoemardjono', 'airazal', 'petroeq', 'agnan1923', 'idoymaridoy', 'mxrozaq', 'anang_ssanto', 'sammyfish13', 'vvchrstn', 'gebmoon', 'newsuriteladan', 'streamingdino', 'riofebrian02', 'dadangadi8', 'weiinnn', 'putirwn', 'raaraapo_', 'soobinjateng', 'dvntnggrn', 'juvejack', 'pokemon_udara', 'snowdropbae', 'agusssshhhhh', '1rfantastic', 'iantrucker', 'awindul', 'officialwawan', 'putrosukarno', 'talakuaelwen95', 'tulip84882930', 'mugiahdht', 'milanista2103', 'lilikshandhie14', 'kutang_hitam', 'dhu_dhuan', 'yotifolk', 'barca_joss', 'kopimovie', 'jeongshafa', 'itsaufarfajar', 'danielandrians', 'baru354', 'ziyadu_r', 'itabmth', 'elichika2525', 'ydknrf', 'adoorabie', 'panggilsajapida', 'achmadbandi', 'asmaraidaleni', 'clynophilert', 'm_kael', 'msnrng', 'rizwandhaimawa1', 'erisadgita', 'itswildanwill', 'flourentt_cris', 'entah3383', 'nell20000', 'witaresw', 'susaaahtidur', 'novita_kaunang', 'reskisural', 'vitabangun', 'marcellrudee', 'tsupersubs', 'novanpramadi12', 'limlim672', 'artregular', 'akbar_gremory', 'officialkjti', 'imanurak_269', 'kancilcungkring', 'msalmanhdr', 'anorexicats', 'himechwaan', 'kak_veronika', 'rose_ifntday6', 'naeni_romayati', 'zerahyaa', 'daffastyaa', 'kokoaja4', 'retywie', 'astagakenapalu', 'kristybambooart', 'andreallian', 'pemudaharapannn', 'ysbcht_', 'ichigo97538820', 'xoneebenaja', 'ndrys_', 'riandi_12', 'estersagala4', 'infoindonesiaaa']
# Banyak Node: 134
# ===========================================
# ['bs_vito', 'triwul82', 'gagaknewww', 'liaisti_1', 'lintang_ayoe', 'antoniuscdn', 'kepaargawinata2', 'budibongg', 'rifqiazizian', 'jilmannurhaman', 'wantahgdn__', 'ipoleksosbudmil', 'urrangawak', 'limbuibui4', 'xiaomei_99', 'r_min80', 'l0ve1ndonesia', 'bahamasjefry', '__rismawidiono_', 'ex_anaklolina', 'jauryjss', 'kotjo3', 'seruanhl', '_tenggangrasa', 'gi_n0ng', 'iromismet', '_25selawe', 'woda_johan', 'nkri_jokowisyoo', 'reymondabraham', 'kadekchandra', 'karyopahing', 'inilahdotcom', 'abdoeljegger202', 'bagiwang', 'bintangkec1l', 'wwleebest', 'rriskand', 'rian__az', 'xc1r3ng', 'itsmmm_13', 'wongkalibanteng', 'denmaspudji', 'hi_wonderwomen', 'naydonuts', 'abidinznl', 'nala_amirah', 'wo2_anis_orba_', 'rmlpas', 'dir1ku', 'p3weeice', 'jumianto_rk', 'prsdenri', 'chairilamri12', 'rahmans22161246', 'ngilmukantilaku', 'cahango45022699', 'abingsanca', 'ojayo_halim']
# Banyak Node: 59
# ===========================================
# ['hansunriko', 'rii1naa', 'forjakeu', 'alshaibashihab', 'akomeng6', 'bank_aconk', 'yohanes_arb', 'rasyamahardika7', 'celebes07', 'anggita_lung', 'indones1akeren_', 'ranisor', 'aryprasetyo85', 'kalla_jengking', 'rasa2086', 'torrez_20_06', 'yulia_ns79', 'irakoestomo', 'komatkamiit', 'otak_sesendok', '_garu_da', 'id_emas2045', 'thoyiblupaplng', 'angelamaziiing', 'iqbalink13', 'apolloresor', 'magarapoo', 'putri_chiki', 'kkajikkaji', 'farahnathan24', 'ayahfarrel02', 'alves_ag88', 'aileenanjani', 'indones1aku', 'catatankaqihati', 'mosesrosi', 'musarudy_stpl', 'zheyenk26', 'nsjayaid', 'minietweets_', 'm1iikii', 'brudak_ultramen', 'inibarudak_well', 'laraswa2529']
# Banyak Node: 44
# ===========================================

# %%
print("Node dengan degree terbanyak:")
# Sort the dictionaries based on their values in descending order
sorted_dicts = sorted(node_degrees_arr, key=lambda x: max(x.values()), reverse=True)
sorted_dicts_highestvalue = [{k: v for k, v in sorted(d.items(), key=lambda x: x[1], reverse=True)} for d in sorted_dicts]
# Print the top two dictionaries

top5nodecommunities = []
for i in sorted_dicts_highestvalue[:5]:
    mostNode=list(i.keys())
    firstMostNode=mostNode[0]
    top5nodecommunities.append(firstMostNode)
    print(top5nodecommunities)
    print(len(i))
    print(i)
    
print("===========================================")
print(top5nodecommunities)
# Out:
# Node dengan degree terbanyak:
# ['detikcom']
# 134
# {'detikcom': 132, 'ockysaputraa': 2, 'baru354': 1, 'akbar_gremory': 1, 'langx_wiratama': 1, 'kak_veronika': 1, 'ysbcht_': 1, 'airazal': 1, 'alimudi84052003': 1, 'ziyadu_r': 1, 'retywie': 1, 'rose_ifntday6': 1, 'eknug': 1, 'msnrng': 1, 'salwafhr30': 1, 'awindul': 1, 'msalmanhdr': 1, 'pemudaharapannn': 1, 'raaraapo_': 1, 'agusssshhhhh': 1, 'lilikshandhie14': 1, 'xoneebenaja': 1, 'msmyoibae': 1, 'yuskareem63': 1, 'abehanief': 1, 'selasa98': 1, 'shandyjepret': 1, 'putirwn': 1,
# ['detikcom', 'yradianto', 'asumsico', 'triwul82']
# 59
# {'triwul82': 43, 'inilahdotcom': 7, 'gi_n0ng': 4, 'woda_johan': 3, 'cahango45022699': 3, 'iromismet': 2, 'nkri_jokowisyoo': 2, 'kadekchandra': 2, '_tenggangrasa': 2, 'r_min80': 1, 'dir1ku': 1, 'budibongg': 1, 'rmlpas': 1, 'prsdenri': 1, 'ngilmukantilaku': 1, 'hi_wonderwomen': 1, 'lintang_ayoe': 1, 'gagaknewww': 1, 'bintangkec1l': 1, '_25selawe': 1, 'abidinznl': 1, 'abingsanca': 1, 'antoniuscdn': 1, 'rriskand': 1, 'jilmannurhaman': 1, 'chairilamri12': 1, 'reymondabraham': 1, 'ex_anaklolina': 1, 'wo2_anis_orba_': 1, 'seruanhl': 1, 'bagiwang': 1, 'kepaargawinata2': 1, 'wongkalibanteng': 1, 'denmaspudji': 1, 'wwleebest': 1, 'urrangawak': 1, 'naydonuts': 1, 'jauryjss': 1, 'rahmans22161246': 1, 'xiaomei_99': 1, 'bahamasjefry': 1, 'bs_vito': 1, 'kotjo3': 1, 'ipoleksosbudmil': 1, 'abdoeljegger202': 1, 'p3weeice': 1, 'rifqiazizian': 1, 'wantahgdn__': 1, 'rian__az': 1, 'nala_amirah': 1, 'l0ve1ndonesia': 1, '__rismawidiono_': 1, 'karyopahing': 1, 'xc1r3ng': 1, 'limbuibui4': 1, 'liaisti_1': 1, 'jumianto_rk': 1, 'ojayo_halim': 1, 'itsmmm_13': 1}
# ['detikcom', 'yradianto', 'asumsico', 'triwul82', '_garu_da']
# 44
# {'_garu_da': 26, 'torrez_20_06': 26, 'bank_aconk': 24, 'forjakeu': 23, 'komatkamiit': 22, 'hansunriko': 21, 'yulia_ns79': 16, 'indones1akeren_': 7, 'akomeng6': 7, 'rasyamahardika7': 7, 'celebes07': 7, 'thoyiblupaplng': 7, 'alshaibashihab': 7, 'iqbalink13': 6, 'apolloresor': 6, 'ranisor': 6, 'anggita_lung': 6, 'yohanes_arb': 6, 'rii1naa': 5, 'otak_sesendok': 5, 'putri_chiki': 4, 'catatankaqihati': 4, 'indones1aku': 3, 'ayahfarrel02': 3, 'rasa2086': 2, 'irakoestomo': 2, 'kalla_jengking': 2, 'zheyenk26': 2, 'musarudy_stpl': 1, 'farahnathan24': 1, 'alves_ag88': 1, 'm1iikii': 1, 'angelamaziiing': 1, 'mosesrosi': 1, 'brudak_ultramen': 1, 'aileenanjani': 1, 'kkajikkaji': 1, 'laraswa2529': 1, 'id_emas2045': 1, 'nsjayaid': 1, 'minietweets_': 1, 'magarapoo': 1, 'aryprasetyo85': 1, 'inibarudak_well': 1}
# ===========================================
# ['detikcom', 'yradianto', 'asumsico', 'triwul82', '_garu_da']

# %%
class FindUser:
    def __init__(self, data, user):
        self.data = data
        self.user = user
        self.found = False
        self.author = None
        self.title = None
        self.label = None
        for i in data.index:
            if(data['author'][i].lower() == self.user):
                self.author = data['author'][i]
                self.title = data['title'][i]
                self.label = data['sentiment_label'][i]
                self.found = True
                break            

    def title(self):
        if(self.title):
            return self.title
    
    def label(self):
        if(self.label):
            return self.label

    def author(self):
        if(self.author):
            return self.author

count = 0
for items in top5nodecommunities:
    count= count+1
    data1 = pd.read_csv('IKN_Nusantara_new.csv')
    community = items
    firstuser = items
    user = FindUser(data1, firstuser)
    print(firstuser)
    print("Komunitas", count, ":", community)
    print("User: ", user.author, end="\n")
    print("Tweet: ", user.title, end="\n")
    print("Label: ", user.label, end="\n")
    print("===========================================")
# Out:
# detikcom
# Komunitas 1 : detikcom
# User:  detikcom
# Tweet:  Sebanyak 2.500 Aparatur Sipil Negara (ASN) akan mulai dipindah secara bertahap ke Ibu Kota Negara (IKN) Nusantara, Kalimantan Timur (Kaltim) tahun 2024. #ASN #IKN  Via: @detik_sulsel  https://t.co/ckujwYoIRT
# Label:  Positive
# ===========================================
# yradianto
# Komunitas 2 : yradianto
# User:  YRadianto
# Tweet:  Pohon Hayat  Inilah Pohon Hayat yang diresmikan Presiden Joko Widodo sebagai logo Ibu Kota Nusantara di Istana Negara Jakarta kemarin (30 Mei 2023).  Selamat dan terima kasih buat Mas Aulia Akbar yang desainnya terpilih.  https://t.co/VzLNOxxUhj https://t.co/PfbmlJL4gv
# Label:  Positive
# ===========================================
# asumsico
# Komunitas 3 : asumsico
# User:  asumsico
# Tweet:  Pemerintah secara terbuka mengajak seluruh masyarakat Indonesia untuk berpartisipasi memilih logo kota Nusantara sebagai Ibu Kota Negara yang baru. https://t.co/SmMZFVFWtJ
# Label:  Positive
# ===========================================
# triwul82
# Komunitas 4 : triwul82
# User:  triwul82
# Tweet:  Pemerintah menggelar pemilihan logo Ibu Kota Negara (IKN) Nusantara berhadiah sepeda motor listrik. Pemilihan logo ini bisa diikuti masyarakat umum. Logo dengan pemilih terbanyak nantinya akan digunakan sebagai logo resmi IKN. Proses pemilihan (voting) logo IKN Nusantara sudah… https://t.co/VUxp9Ui73j https://t.co/JC7T0QuDvj
# Label:  Positive
# ===========================================
# _garu_da
# Komunitas 5 : _garu_da
# User:  _garu_da
# Tweet:  RT @Komatkamiit: Alhamdulillah bisa bernafas lega.  Exco PSSI Arya Sinulingga ungkapkan sanksi FIFA tidak memengaruhi rencana membangun tra…
# Label:  Positive
# ===========================================

# %%
class FindUser:
    def __init__(self, data, user):
        self.data = data
        self.user = user
        self.found = False
        self.reply = None
        self.rt = None
        for i in data.index:
            if(data['author'][i].lower() == self.user):
                self.author = data['author'][i]
                self.title = data['title'][i]
                self.label = data['sentiment_label'][i]
                self.found = True
                break
            self.author = None
            self.title = None
            self.label = None

    def retweet(self):
        retweets = []
        for i in data.index:
            if(str(self.data['retweeted_screen_name'][i]).lower() == self.user):
                retweets.append(self.data['author'][i])
        # if retweets:
        #     return retweets
        return retweets
        # print(self.retweet)
    
    def reply(self):
        replys = []
        for i in data.index:
            user = data['in_reply_to_screen_name'][i]
            if(user == self.user):
                if(self.data['in_reply_to_screen_name'][i] != self.data['author'][i]):
                    replys.append([self.data['author'][i], self.data['description'][i]])
        if replys:
            return replys
        return None

data2 = pd.read_csv('IKN_Nusantara.csv')
author = "yradianto"
author_lower = author
user2 = FindUser(data2, author_lower)
retweets2 = user2.retweet()
print(author_lower)
print(retweets2)
print("===========================================")

count = 0
for items in top5nodecommunities:
    count= count+1
    data1 = pd.read_csv('IKN_Nusantara.csv')
    community = items
    firstuser = items
    user = FindUser(data1, firstuser)
    retweets = user.retweet()
    print(firstuser)
    print("Komunitas", count, ":", community)
    print("User: ", user.author, end="\n")
    print("Tweet: ", user.title, end="\n")
    print("Label: ", user.label, end="\n")
    print("Retweet: ", retweets, end="\n")
    print("Reply: ", user.reply, end="\n")
    print("===========================================")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# c:\Users\ASUS\Documents\Coding\Phyton\AJS\Community Detection\ikn27juni2023.ipynb Cell 5 in 4
#      <a href='vscode-notebook-cell:/c%3A/Users/ASUS/Documents/Coding/Phyton/AJS/Community%20Detection/ikn27juni2023.ipynb#W5sZmlsZQ%3D%3D?line=36'>37</a>             return replys
#      <a href='vscode-notebook-cell:/c%3A/Users/ASUS/Documents/Coding/Phyton/AJS/Community%20Detection/ikn27juni2023.ipynb#W5sZmlsZQ%3D%3D?line=37'>38</a>         return None
# ---> <a href='vscode-notebook-cell:/c%3A/Users/ASUS/Documents/Coding/Phyton/AJS/Community%20Detection/ikn27juni2023.ipynb#W5sZmlsZQ%3D%3D?line=39'>40</a> data2 = pd.read_csv('IKN_Nusantara.csv')
#      <a href='vscode-notebook-cell:/c%3A/Users/ASUS/Documents/Coding/Phyton/AJS/Community%20Detection/ikn27juni2023.ipynb#W5sZmlsZQ%3D%3D?line=40'>41</a> author = "yradianto"
#      <a href='vscode-notebook-cell:/c%3A/Users/ASUS/Documents/Coding/Phyton/AJS/Community%20Detection/ikn27juni2023.ipynb#W5sZmlsZQ%3D%3D?line=41'>42</a> author_lower = author
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608     return parser
#     610 with parser:
# --> 611     return parser.read(nrows)
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1778, in TextFileReader.read(self, nrows)
#    1771 nrows = validate_integer("nrows", nrows)
#    1772 try:
#    1773     # error: "ParserBase" has no attribute "read"
#    1774     (
#    1775         index,
#    1776         columns,
#    1777         col_dict,
# -> 1778     ) = self._engine.read(  # type: ignore[attr-defined]
#    1779         nrows
#    1780     )
#    1781 except Exception:
#    1782     self.close()
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:230, in CParserWrapper.read(self, nrows)
#     228 try:
#     229     if self.low_memory:
# --> 230         chunks = self._reader.read_low_memory(nrows)
#     231         # destructive to chunks
#     232         data = _concatenate_chunks(chunks)
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\parsers.pyx:808, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\parsers.pyx:866, in pandas._libs.parsers.TextReader._read_rows()
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\parsers.pyx:852, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\parsers.pyx:1965, in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe2 in position 254048: invalid continuation byte
